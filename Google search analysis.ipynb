# %%
pip install pytrends
# Out:
# Requirement already satisfied: pytrends in c:\users\gaura\anaconda3\lib\site-packages (4.9.0)
# Requirement already satisfied: requests>=2.0 in c:\users\gaura\anaconda3\lib\site-packages (from pytrends) (2.27.1)
# Requirement already satisfied: lxml in c:\users\gaura\anaconda3\lib\site-packages (from pytrends) (4.8.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\gaura\anaconda3\lib\site-packages (from pytrends) (1.4.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\gaura\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gaura\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\gaura\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gaura\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.25->pytrends) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gaura\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gaura\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gaura\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\gaura\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
#analyzing the Google search trends on the queries based on “Machine Learning”

trends.build_payload(kw_list=["Machine Learning"])
data=trends.interest_by_region()
data = data.sort_values(by="Machine Learning", ascending=False)
data = data.head(10)
print(data)
# Out:
#              Machine Learning
# geoName
# China                     100
# Ethiopia                   47
# Singapore                  47
# St. Helena                 36
# India                      36
# Pakistan                   26
# Hong Kong                  24
# Tunisia                    24
# Nepal                      23
# South Korea                22

# %%
data.reset_index().plot(x="geoName", 
                        y="Machine learning", 
                        figsize=(15,5), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
#Keyword over the time

data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Machine learning'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15, 12))
data['Machine learning'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Machine Learning', 
          fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
